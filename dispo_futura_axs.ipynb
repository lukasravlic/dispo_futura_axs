# %%
#IMPORTACION DE LIBRERIAS
import pandas as pd
import datetime
import os
import numpy as np
import getpass

hoy = datetime.datetime.today()
hoy = datetime.date(2024,10,14)
#LECTURA DE DFS
from pathlib import Path
usuario = getpass.getuser()

# %%
ruta = f'C:/Users/{usuario}/Inchcape/Planificación y Compras Chile - Documentos/Bases Indicadores en CSV {hoy.year}-{hoy.month:02d}'
ruta_repo = Path(ruta)

# %%
import pandas as pd

def excel_to_dataframe(xl_name: str, sh_name: str) -> pd.DataFrame:
    """
    Convert an Excel sheet to a pandas DataFrame.

    :param xl_name: The path to the Excel file.
    :param sh_name: The name of the sheet to be read.
    :return: A pandas DataFrame containing the data from the specified Excel sheet.
    """
    # Load the Excel file
    xls = pd.ExcelFile(xl_name)
    
    # Parse the specified sheet into a DataFrame
    df = xls.parse(sh_name)
    
    return df

# Example usage:

# %%
dtypes = {'Material actual':'str'}

# %%
df_sp = pd.read_excel("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras OEM/Planificación/Plan de Compras/2024/07 Julio 24/SP Julio V2.xlsx", sheet_name='Base', dtype = dtypes)

# %%
columnas= ['Nro_pieza_fabricante_1',	'Cod_Actual_1']
ruta_cod = ruta_repo.joinpath('COD_ACTUAL.csv')

# Leer el archivo CSV en un DataFrame
cadena_de_remplazo = pd.read_csv(ruta_cod)
cadena_de_remplazo = cadena_de_remplazo[columnas]

# %%
#MARA
columnas_mara = ['Material_R3','Part_number','Material_dsc','Modelo','Familia', 'Subfamilia', 'Categoría', 'Subcatgería','Sector_dsc']
ruta_mara = ruta_repo.joinpath('MARA_R3.csv')

# Leer el archivo CSV en un DataFrame
df_mara = pd.read_csv(ruta_mara)

print('Ruta Mara: ' + '\n' + str(ruta_mara))
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_27308\3838735803.py:6: DtypeWarning: Columns (4,11,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mara = pd.read_csv(ruta_mara)
# Ruta Mara:
# C:\Users\lravlic\Inchcape\Planificación y Compras Chile - Documentos\Bases Indicadores en CSV 2024-08\MARA_R3.csv

# %%
#OBSOLECENCIA
#OBSOLECENCIA
columnas = ['ZFI_INNV1_T','ZFI_INNV2_T','ZFI_INNV3_T','ZFI_INNV4_T','ZFI_INNV5_T','ZFI_INNV6_T','ZFI_INNV7_T','sociedad_orig','Último Eslabón','Centro','obso_inchcape']

# for i in lista_maestro:
#     if 'new_obso' in i:
#         carpeta_obso = ruta_maestro + '/' + i
# df_obs_1 = excel_to_dataframe(carpeta_obso,'Base Obs Cierre Abr-24')

ruta_obs = ruta_repo.joinpath('OBSOLECENCIA.csv')

# Leer el archivo CSV en un DataFrame
df_obs_1 = pd.read_csv(ruta_obs)
df_obs_1 = df_obs_1[columnas]
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_27308\1454707797.py:13: DtypeWarning: Columns (4,75,76,77,78,79,84,89,91,97,101,102,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_obs_1 = pd.read_csv(ruta_obs)

# %%
# ruta_lt = "LT Actuales Mar-24.xlsx"
# df_lt = pd.read_excel(ruta_lt, header=1)
# #STOCK
ruta_tubo = "C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Tubo Semanal"
carpetas_tubo = os.listdir(ruta_tubo)
tubo = carpetas_tubo[-2]
ubi_tubo = ruta_tubo + '/' + tubo + '/' + tubo
archivo_tr = ruta_tubo + '/' + tubo + '/' + tubo + ' - TR FINAL R3 - Consolidado.xlsx'
archivo_tubo = ruta_tubo + '/' + tubo + '/' + tubo + ' - Stock R3.xlsx'
print(tubo)
dtypes = {'Almacén':'str', 'Centro':'str'}
# dtypes = {'Almacén':'str'}
df_stock = pd.read_excel(archivo_tubo, dtype = dtypes,sheet_name = 'Sheet1')


# #TRANSITO
df_tr = pd.read_excel(archivo_tr,sheet_name = 'Sheet1')
# Out:
# 2024-08-12

# %%
#Reseteo de OBS
df_sp_1 = df_sp
df_obs = df_obs_1

# %%
df_obs_1 = df_obs_1.rename(columns={'Último Eslabón': 'Ultimo Eslabon'}, inplace = True)

# %% [markdown]
# LECTURA CAD REMPLAZO

# %%
df_sp_1 = df_sp_1.merge(cadena_de_remplazo, left_on='Material actual', right_on='Nro_pieza_fabricante_1', how='left')
df_sp_1['Cod_Actual_1'] = df_sp_1['Cod_Actual_1'].fillna(df_sp_1['Material actual'])
df_sp_1 = df_sp_1.drop('Nro_pieza_fabricante_1', axis=1)

# %%
df_codigo = df_sp_1[df_sp_1['Vigencia Derco']==1]

# %%
df_codigo.drop_duplicates(subset='Material actual', inplace=True)
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_27308\549681374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_codigo.drop_duplicates(subset='Material actual', inplace=True)

# %%
df_mara.drop_duplicates(subset='Material_R3', inplace=True)

# %%
df_codigo.columns.to_list()
# Out:
# ['Material actual',
#  'Descripción',
#  'Sector',
#  'Familia',
#  'Subfamilia',
#  'Categoría',
#  'Subcategoría',
#  'Factor',
#  'Cod. Proveedor',
#  'Proveedor',
#  'Considerar?',
#  'Lead Time',
#  'Origen',
#  'Costo Un',
#  'Precio Neto',
#  'Moneda',
#  'Nuevo',
#  'PDI',
#  'CES',
#  'Vigencia Derco',
#  'Campo 1',
#  'Costo Final',
#  'Tipo',
#  'Campo 2',
#  'Inquiebrables',
#  datetime.datetime(2024, 6, 15, 0, 0),
#  datetime.datetime(2024, 7, 15, 0, 0),
#  datetime.datetime(2024, 8, 15, 0, 0),
#  datetime.datetime(2024, 9, 15, 0, 0),
#  datetime.datetime(2024, 10, 15, 0, 0),
#  datetime.datetime(2024, 11, 15, 0, 0),
#  datetime.datetime(2024, 12, 15, 0, 0),
#  datetime.datetime(2025, 1, 15, 0, 0),
#  datetime.datetime(2025, 2, 15, 0, 0),
#  datetime.datetime(2025, 3, 15, 0, 0),
#  datetime.datetime(2025, 4, 15, 0, 0),
#  datetime.datetime(2025, 5, 15, 0, 0),
#  'Ẍ 3 Meses',
#  'X6 (Sin STK Piso)',
#  datetime.datetime(2023, 3, 1, 0, 0),
#  datetime.datetime(2023, 4, 1, 0, 0),
#  datetime.datetime(2023, 5, 1, 0, 0),
#  datetime.datetime(2023, 6, 1, 0, 0),
#  datetime.datetime(2023, 7, 1, 0, 0),
#  datetime.datetime(2023, 8, 1, 0, 0),
#  datetime.datetime(2023, 9, 1, 0, 0),
#  datetime.datetime(2023, 10, 1, 0, 0),
#  datetime.datetime(2023, 11, 1, 0, 0),
#  datetime.datetime(2023, 12, 1, 0, 0),
#  datetime.datetime(2024, 1, 1, 0, 0),
#  datetime.datetime(2024, 2, 1, 0, 0),
#  datetime.datetime(2024, 3, 1, 0, 0),
#  datetime.datetime(2024, 4, 1, 0, 0),
#  datetime.datetime(2024, 5, 1, 0, 0),
#  'Ẍ SIMPLE',
#  'Ẍ 3 - 6 - 12',
#  'Ultimos Mes Vta Alta (arreglar, Cruzar)',
#  '2024-06-15 00:00:00.1',
#  '2024-07-15 00:00:00.1',
#  '2024-08-15 00:00:00.1',
#  '2024-09-15 00:00:00.1',
#  '2024-10-15 00:00:00.1',
#  '2024-11-15 00:00:00.1',
#  '2024-12-15 00:00:00.1',
#  '2025-01-15 00:00:00.1',
#  '2025-02-15 00:00:00.1',
#  '2025-03-15 00:00:00.1',
#  '2025-04-15 00:00:00.1',
#  '2025-05-15 00:00:00.1',
#  'Quiebre',
#  'Mes Revision',
#  'Mes Llegada',
#  'Stock Esperado',
#  'Demanda A Cubrir',
#  'Stock De Seguridad',
#  'Pedido Exacto',
#  'Inner Case',
#  'Pedido Con MOQ',
#  'Δ Pedido MOQ',
#  'Pedido Con Inner',
#  'MOQ',
#  'Δ Pedido Final',
#  'Δ Pedido $',
#  'Pedido Final',
#  'Tránsito Total',
#  '2024-06-15 00:00:00.2',
#  '2024-07-15 00:00:00.2',
#  '2024-08-15 00:00:00.2',
#  '2024-09-15 00:00:00.2',
#  '2024-10-15 00:00:00.2',
#  '2024-11-15 00:00:00.2',
#  '2024-12-15 00:00:00.2',
#  '2025-01-15 00:00:00.2',
#  '2025-02-15 00:00:00.2',
#  '2025-03-15 00:00:00.2',
#  '2025-04-15 00:00:00.2',
#  '2025-05-15 00:00:00.2',
#  'Obsolescencia',
#  'Stock Pañol',
#  'Stock 0710 - 0711',
#  'Stock CD',
#  'Stock',
#  'Stock $',
#  'Int. Compra',
#  'Plan Híbrido UN',
#  'Plan Híbrido $',
#  'MOS',
#  'Refuerzo MOS',
#  'Refuerzo MOS $',
#  'Plan Híbrido Total UN',
#  'Plan Híbrido Total $',
#  'MOS < 2 NAC',
#  'FC $ jun-24',
#  'FC $ jul-24',
#  'FC $ ago-24',
#  'FC $ sep-24',
#  'FC $ oct-24',
#  'FC $ nov-24',
#  'FC $ dic-24',
#  'FC $ ene-25',
#  'FC $ feb-25',
#  'FC $ mar-25',
#  'FC $ abr-25',
#  'FC $ may-25',
#  'Stock jun-24',
#  'Stock jul-24',
#  'Stock ago-24',
#  'Stock sep-24',
#  'Stock oct-24',
#  'Stock nov-24',
#  'Stock dic-24',
#  'Stock ene-25',
#  'Stock feb-25',
#  'Stock mar-25',
#  'Stock abr-25',
#  'Stock mar-25.1',
#  'TR$ jun-24',
#  'TR$ jul-24',
#  'TR$ ago-24',
#  'TR$ sep-24',
#  'TR$ oct-24',
#  'TR$ nov-24',
#  'TR$ dic-24',
#  'TR$ ene-25',
#  'TR$ feb-25',
#  'TR$ mar-25',
#  'TR$ abr-25',
#  'TR$ may-25',
#  'Total TR$',
#  'Input PM',
#  'Vigencia',
#  'Primera Compra Nuevo',
#  'FC $',
#  'FC$ (Sin Stock Piso)',
#  'Venta $',
#  'Cobertura FC',
#  'Stokc Pañol',
#  'Stock Pañol $ ',
#  'Stock $.1',
#  'Promedio FC (3M) $',
#  'Venta Promedio (6M) $',
#  'FC Promedio 6M',
#  'Stock Pañol Teórico(LT)$',
#  'Stock TR Teórico(LT)$',
#  'Stock CD Teórico (SS+PR)$',
#  'LT MES',
#  'Planificable',
#  'Stock Pañol Teórico(LT)$.1',
#  'Stock TR Teórico P(LT)$',
#  'Stock CD Teórico P(SS+PR)$',
#  'Unnamed: 170',
#  'Unnamed: 171',
#  'Unnamed: 172',
#  'Cod_Actual_1']

# %%
df_codigo = df_codigo[['Material actual','Cod_Actual_1','Descripción','Cod. Proveedor','Proveedor','Plan Híbrido UN','Origen','CES','PDI','Nuevo','Lead Time']]

# %%
df_base = pd.merge(df_codigo, df_mara, left_on = 'Cod_Actual_1', right_on='Material_R3', how='left')
df_base['Part_number'] = df_base['Part_number'].str.replace(r'\[\#\]', '', regex=True)

# %%
ruta_fc = f"C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras OEM/Demanda/Forecast Inbound/{(hoy).year}"
lista_fc = os.listdir(ruta_fc)
for i in lista_fc:
    if str(hoy.year) in i and str((hoy).month-1).zfill(2) in i:
        archivos_fc = os.listdir(ruta_fc + '/' + i)
        for j in archivos_fc:
            if 'AXS' in j:
                archivo = ruta_fc + '/' + i + '/' + j 
                print("Archivo Forecast: "+ '\n' + str(archivo))
                df_fc = pd.read_excel(archivo,  sheet_name='Inbound SP', header=3,engine='openpyxl')
# Out:
# Archivo Forecast:
# C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras OEM/Demanda/Forecast Inbound/2024/2024-07 Julio/AXS
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[22], line 10
#       8 archivo = ruta_fc + '/' + i + '/' + j
#       9 print("Archivo Forecast: "+ '\n' + str(archivo))
# ---> 10 df_fc = pd.read_excel(archivo,  sheet_name='Inbound SP', header=3,engine='openpyxl')
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:572, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     568 self.handles = IOHandles(
#     569     handle=filepath_or_buffer, compression={"method": None}
#     570 )
#     571 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 572     self.handles = get_handle(
#     573         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     574     )
#     576 if isinstance(self.handles.handle, self._workbook_class):
#     577     self.book = self.handles.handle
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras OEM/Demanda/Forecast Inbound/2024/2024-07 Julio/AXS'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_fc_final = ['Último Eslabón']
for item in df_fc.columns.to_list()[-12:]:
    df_fc_final.append(item)

# %%
df_fc_final
# Out:
# ['Último Eslabón',
#  'Suma de jun-243',
#  'Suma de jul-243',
#  'Suma de ago-243',
#  'Suma de sept-243',
#  'Suma de oct-243',
#  'Suma de nov-243',
#  'Suma de dic-243',
#  'Suma de ene-253',
#  'Suma de feb-253',
#  'Suma de mar-253',
#  'Suma de abr-253',
#  'Suma de may-253']

# %%
df_fc_prom = df_fc[df_fc_final]

# %%
df_fc_prom
# Out:
#        Último Eslabón  Suma de jun-243  Suma de jul-243  Suma de ago-243  \
# 0          8201356709         0.000000         0.000000         0.000000
# 1      73821M68P005PK         5.818182         5.983471         5.618332
# 2           A04PZD-M1         0.000000         0.000000         0.000000
# 3              PD1174         0.000000         0.000000         0.000000
# 4        CAMNC-AC2SHD         0.000000         0.000000         0.000000
# ..                ...              ...              ...              ...
# 950            202204         0.000000         0.000000         0.000000
# 951    DASHCAMHK30PRO         0.000000         0.000000        50.000000
# 952  EXTINTORCO2BC5KG        10.000000         0.000000         4.000000
# 953         PATSERIEM         0.000000         0.000000         0.000000
# 954     Total general     80289.029668     31028.688103     37498.555763
#
#      Suma de sept-243  Suma de oct-243  Suma de nov-243  Suma de dic-243  \
# 0            0.000000         0.000000         0.000000         0.000000
# 1            5.310908         5.339172         5.642733         5.701163
# 2            0.000000         0.000000         0.000000         0.000000
# 3            0.000000         0.000000         0.000000         0.000000
# 4            0.000000         0.000000         0.000000         0.000000
# ..                ...              ...              ...              ...
# 950          2.000000         0.000000         0.000000         0.000000
# 951         50.000000        50.000000         0.000000         0.000000
# 952          2.000000         3.000000         4.000000         1.000000
# 953          0.000000         0.000000         0.000000         0.000000
# 954      32856.651330     31489.657985     31639.228807     33884.312439
#
#      Suma de ene-253  Suma de feb-253  Suma de mar-253  Suma de abr-253  \
# 0           0.000000         0.000000         0.000000         0.000000
# 1           5.310360         5.429484         5.832164         5.362361
# 2           0.000000         0.000000         0.000000         0.000000
# 3           0.000000         0.000000         0.000000         0.000000
# 4           0.000000         0.000000         0.000000         0.000000
# ..               ...              ...              ...              ...
# 950         0.000000         0.000000         0.000000         0.000000
# 951         0.000000         0.000000         0.000000         0.000000
# 952         0.000000         0.000000         0.000000         0.000000
# 953         0.000000         0.000000         0.000000         0.000000
# 954     32804.539683     26960.239934     24324.521933     28675.502358
#
#      Suma de may-253
# 0           0.000000
# 1           5.577121
# 2           0.000000
# 3           0.000000
# 4           0.000000
# ..               ...
# 950         0.000000
# 951         0.000000
# 952         0.000000
# 953         0.000000
# 954     23667.344285
#
# [955 rows x 13 columns]

# %%
df_fc_prom = df_fc_prom.merge(cadena_de_remplazo, left_on='Último Eslabón', right_on='Nro_pieza_fabricante_1', how ='left')
df_fc_prom['Cod_Actual_1'] = df_fc_prom['Cod_Actual_1'].fillna(df_fc_prom['Último Eslabón'])
df_fc_prom
df_fc_prom.columns.to_list()
df_fc_prom.drop(columns=['Último Eslabón','Nro_pieza_fabricante_1'], inplace=True)
columnas_prom = [col for col in df_fc_prom.columns if 'Suma' in col]
df_fc_prom
df_fc_prom.columns = [col.replace('Suma de', 'FC') for col in df_fc_prom.columns]
df_fc_prom.columns = [col.replace('sept', 'sep')  for col in df_fc_prom.columns]
# columnas_seleccionadas = ['Cod_Actual_1'] + [col for col in df_fc_prom.columns if 'FC' in col and 'Prom' not in col][:10]

# nuevo_df_fc_prom = df_fc_prom[columnas_seleccionadas].copy()
df_fc_prom = df_fc_prom.groupby('Cod_Actual_1').sum()
df_fc_prom = df_fc_prom.reset_index()

df_fc_prom.columns = [col[:-1] if col.endswith('3') else col for col in df_fc_prom.columns]

# %%
df_fc_prom.columns
# Out:
# Index(['Cod_Actual_1', 'FC jun-24', 'FC jul-24', 'FC ago-24', 'FC sep-24',
#        'FC oct-24', 'FC nov-24', 'FC dic-24', 'FC ene-25', 'FC feb-25',
#        'FC mar-25', 'FC abr-25', 'FC may-25'],
#       dtype='object')

# %%
# Filter columns that start with 'FC'
columns_to_process = [col for col in df_fc_prom.columns if col.startswith('FC')]

df_fc_prom['Promedio FC'] = df_fc_prom[columns_to_process[1:4]].mean(axis=1)
df_fc_prom['Promedio FC Piso'] = df_fc_prom[columns_to_process[0:3]].mean(axis=1)

#Multiply the first column by 0.33 and add the result to each of the next three columns
multiplied_column = df_fc_prom[columns_to_process[0]] * 0.333
for col in columns_to_process[1:4]:
    df_fc_prom[col] += multiplied_column
    #print(col)



for col in columns_to_process:
    df_fc_prom[col] = df_fc_prom[col]/4.33

for col in columns_to_process:
    print(col)




#Drop the first column
df_fc_prom['Stock de piso'] = df_fc_prom[columns_to_process[0]] 
df_fc_prom.drop(columns_to_process[0], axis=1, inplace=True)
# Out:
# FC jun-24
# FC jul-24
# FC ago-24
# FC sep-24
# FC oct-24
# FC nov-24
# FC dic-24
# FC ene-25
# FC feb-25
# FC mar-25
# FC abr-25
# FC may-25

# %%
df_fc_final_venta = ['Último Eslabón']
for item in [col for col in df_fc.columns if 'Suma' in col and not 'Vigencia' in col][:-12]:
    df_fc_final_venta.append(item)

# %%
df_fc_final_venta
# Out:
# ['Último Eslabón',
#  'Suma de mar-24',
#  'Suma de abr-24',
#  'Suma de may-24',
#  'Suma de jun-24',
#  'Suma de jul-24',
#  'Suma de ago-24',
#  'Suma de sept-24',
#  'Suma de oct-24',
#  'Suma de nov-24',
#  'Suma de dic-24',
#  'Suma de ene-25',
#  'Suma de feb-25',
#  'Suma de mar-25',
#  'Suma de abr-25',
#  'Suma de may-25']

# %%
df_fc_prom_venta = df_fc[df_fc_final_venta]

# %%
df_fc_prom_venta = df_fc_prom_venta.merge(cadena_de_remplazo, left_on='Último Eslabón', right_on='Nro_pieza_fabricante_1', how ='left')
df_fc_prom_venta['Cod_Actual_1'] = df_fc_prom_venta['Cod_Actual_1'].fillna(df_fc_prom_venta['Último Eslabón'])
df_fc_prom_venta.drop(columns=['Último Eslabón','Nro_pieza_fabricante_1'], inplace=True)
columnas_prom_venta = [col for col in df_fc_prom_venta.columns if 'Suma' in col]
df_fc_prom_venta['Promedio Venta'] = df_fc_prom_venta[columnas_prom_venta[-12:]].mean(axis=1)
# columnas_seleccionadas = ['Cod_Actual_1'] + [col for col in df_fc_prom.columns if 'FC' in col and 'Prom' not in col][:10]
# nuevo_df_fc_prom = df_fc_prom[columnas_seleccionadas].copy()


df_fc_prom_venta = df_fc_prom_venta[['Cod_Actual_1', 'Promedio Venta']]
df_fc_prom_venta = df_fc_prom_venta.groupby(['Cod_Actual_1'])['Promedio Venta'].sum().reset_index()

# %%
df_stock['Total'] = df_stock['Libre utilización'] + df_stock['Trans./Trasl.'] + df_stock['En control calidad']

# Eliminar las columnas no necesarias
columns_to_drop = ['Libre utilización', 'Trans./Trasl.', 'En control calidad']
df_stock = df_stock.drop(columns=columns_to_drop)

# Filtrar las filas que cumplen con las condiciones especificadas
condicion = (
    ((df_stock['Centro'] == '201') & (df_stock['Almacén'] == '1100'))
)

condicion_2 = (
    ((df_stock['Almacén'] == '1500') | (df_stock['Almacén'] == '1505')))


df_stock_cd = df_stock[condicion]
df_stock_pañol = df_stock[condicion_2]

# Agrupar por 'Ult. Eslabon' y sumar la columna 'Total'
df_stock_cd = df_stock_cd.groupby(['Ult. Eslabon']).agg({'Total': 'sum'}).reset_index()
df_stock_pañol = df_stock_pañol.groupby(['Ult. Eslabon']).agg({'Total': 'sum'}).reset_index()

# %%
df_base = df_base.merge(df_stock_cd, left_on='Cod_Actual_1', right_on='Ult. Eslabon', how='left')
df_base = df_base.merge(df_stock_pañol, left_on='Cod_Actual_1', right_on='Ult. Eslabon', how='left')

# %%
columnas = {'Total_x':'Stock CD','Total_y':'Stock Pañol'}
columnas_drop = ['Ult. Eslabon_x','Ult. Eslabon_y']
df_base.rename(columns=columnas, inplace=True)
df_base.drop(columns = columnas_drop, inplace=True)

# %%
df_base = df_base.merge(df_fc_prom, left_on='Cod_Actual_1', right_on = 'Cod_Actual_1', how='left')
df_base = df_base.merge(df_fc_prom_venta, left_on='Cod_Actual_1', right_on = 'Cod_Actual_1', how='left')

# %%
def custom_formula(row):
    AH = row['Stock CD']
    T = row['Promedio FC']
    if AH == 0:
        return 0 if T == 0 else (AH / T)
    else:
        return AH / T if T != 0 else 12

# Apply the custom function to the DataFrame
df_base['Cobertura Stock'] = df_base.apply(custom_formula, axis=1)

# %%
df_base['Cobertura Stock'].sum()
# Out:
# 199008.53195964417

# %%
df_sp_costo_1 = df_sp_1[['Material actual','Costo Un']]
df_sp_costo_1.drop_duplicates(subset=['Material actual'], inplace=True)
df_base = df_base.merge(df_sp_costo_1[['Material actual','Costo Un']], left_on='Material actual', right_on='Material actual', how= 'left')
df_sp_costo = df_sp_1[['Cod_Actual_1','Costo Un']].sort_values(by='Costo Un', ascending=False)
df_sp_costo.drop_duplicates(subset=['Cod_Actual_1'], keep='first', inplace=True)
df_base = df_base.merge(df_sp_costo, left_on='Cod_Actual_1', right_on='Cod_Actual_1', how='left')
df_base['Costo Un_x'] = df_base['Costo Un_x'].fillna(df_base['Costo Un_y'])
df_base.drop(['Costo Un_y'], inplace = True, axis=1)
df_base = df_base.rename(columns = {'Costo Un_x':'Costo CPP'})
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2245636534.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp_costo_1.drop_duplicates(subset=['Material actual'], inplace=True)

# %%
df_sp_moq_1 = df_sp_1[['Material actual','Cod_Actual_1','MOQ']]
df_sp_moq_1.drop_duplicates(subset=['Material actual'],keep='first', inplace=True)
df_base = df_base.merge(df_sp_moq_1[['Material actual','MOQ']], left_on='Material actual', right_on='Material actual', how= 'left')
df_sp_moq = df_sp_1[['Cod_Actual_1','MOQ']].sort_values(by='MOQ',ascending=False)
df_sp_moq.drop_duplicates(subset=['Cod_Actual_1'], keep='first', inplace=True)
df_base = df_base.merge(df_sp_moq, left_on='Cod_Actual_1', right_on='Cod_Actual_1', how='left')
df_base['MOQ_x'] = df_base['MOQ_x'].fillna(df_base['MOQ_y'])

df_base = df_base.rename(columns = {'MOQ_x':'MOQ'})
df_base.drop(columns='MOQ_y', inplace=True)
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2884188088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp_moq_1.drop_duplicates(subset=['Material actual'],keep='first', inplace=True)

# %%
df_sp_precio_1 = df_sp_1[['Material actual','Cod_Actual_1','Precio Neto', 'Moneda']]
df_sp_precio_1.drop_duplicates(subset=['Material actual'],keep='first', inplace=True)
df_base = df_base.merge(df_sp_precio_1[['Material actual','Precio Neto','Moneda']], left_on='Material actual', right_on='Material actual', how= 'left')
df_sp_precio = df_sp_1[['Cod_Actual_1','Precio Neto', 'Moneda']].sort_values(by='Precio Neto',ascending=False)
df_sp_precio.drop_duplicates(subset=['Cod_Actual_1'], keep='first', inplace=True)
df_base = df_base.merge(df_sp_precio, left_on='Cod_Actual_1', right_on='Cod_Actual_1', how='left')
df_base['Precio Neto_x'] = df_base['Precio Neto_x'].fillna(df_base['Precio Neto_y'])
df_base['Moneda_x'] = df_base['Moneda_x'].fillna(df_base['Moneda_y'])

df_base = df_base.rename(columns = {'Precio Neto_x':'Precio Neto', 'Moneda_x':'Moneda'})
df_base.drop(columns=['Precio Neto_y','Moneda_y'], inplace=True)
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2026984355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp_precio_1.drop_duplicates(subset=['Material actual'],keep='first', inplace=True)

# %%
df_base['Moneda'].value_counts()
# Out:
# Moneda
# CLP    205
# USD     79
# JPY     52
# EUR     31
# 0       25
# CNY      3
# Name: count, dtype: int64

# %%
df_base['Vigencia Canal'] = df_base.apply(lambda row: 'PDI' if row['PDI'] == 1 else ('CES' if row['CES'] == 1 else 'NUEVO'), axis=1)

# %%
df_base.fillna(0, inplace=True)

# %%
df_base['Menor a 1'] = df_base.apply(lambda row: 'Menor que 1' if row['Promedio Venta'] < 1 else 'Mayor o igual a 1', axis=1)

# %%
# hoy = datetime.date(2024, 6, 5)
hoy = pd.to_datetime(hoy)

# Add the 'Lead Time' to today's date to create the 'Semana LT' column
df_base['Semana LT'] = (hoy + pd.to_timedelta(df_base['Lead Time'], unit='D')).dt.isocalendar().week
df_base['Mes LT'] = (hoy + pd.to_timedelta(df_base['Lead Time'], unit='D')).dt.month

# %%
df_base.groupby(['Mes LT'])['Cod_Actual_1'].count().reset_index().to_clipboard()

# %%
din_obs = df_obs[(df_obs['ZFI_INNV1_T'] == 'CHILE') & 
                 (df_obs['ZFI_INNV2_T'] == 'BACK OFFICE PAISES') & 
                 (df_obs['ZFI_INNV3_T'] == 'SOPORTE PAIS') & 
                 (df_obs['ZFI_INNV4_T'] == 'SOPORTE PAIS') & 
                 (df_obs['ZFI_INNV5_T'] == 'SOPORTE PAIS') & 
                 (df_obs['ZFI_INNV6_T'] == 'OPERACIONES Y LOGIST') & 
                 (df_obs['ZFI_INNV7_T'] == 'PLANIFICACIN Y ABAST') & 
                 (df_obs['sociedad_orig'] == 'CL02') &
                 (df_obs['Centro'] == '0201')]

# %%
din_obs_final = din_obs.groupby('Ultimo Eslabon').sum(['obso_inchcape']).reset_index()

# %%
df_base.columns
# Out:
# Index(['Material actual', 'Cod_Actual_1', 'Descripción', 'Cod. Proveedor',
#        'Proveedor', 'Plan Híbrido UN', 'Origen', 'CES', 'PDI', 'Nuevo',
#        'Lead Time', 'Nro_material', 'Material_dsc', 'Fecha_creacion',
#        'Tipo_material', 'Grupo_articulo', 'Grupo_art_desc',
#        'Grupo_art_externo', 'Nro_material_antiguo', 'Sector', 'Sector_dsc',
#        'Jerarquia_producto', 'Jquia_desc', 'Material_R3', 'Part_number',
#        'Tamaño', 'Material_S4', 'Nodo de Jerarquía', 'Familia', 'Subfamilia',
#        'Categoría', 'Subcatgería', 'Modelo', 'Stock CD', 'Stock Pañol',
#        'FC jul-24', 'FC ago-24', 'FC sep-24', 'FC oct-24', 'FC nov-24',
#        'FC dic-24', 'FC ene-25', 'FC feb-25', 'FC mar-25', 'FC abr-25',
#        'FC may-25', 'Promedio FC', 'Promedio FC Piso', 'Stock de piso',
#        'Promedio Venta', 'Cobertura Stock', 'Costo CPP', 'MOQ', 'Precio Neto',
#        'Moneda', 'Vigencia Canal', 'Menor a 1', 'Semana LT', 'Mes LT'],
#       dtype='object')

# %% [markdown]
# NO SE ENCUENTRAN LOS ARCHIVOS NI DE LT NI OBSOLECENCIA

# %%
df_base = df_base.merge(din_obs_final,left_on='Cod_Actual_1', right_on='Ultimo Eslabon', how='left')

# %%
df_base.fillna(0, inplace=True)

# %%
df_base['Obsolescencia'] = np.where(df_base['obso_inchcape'].notna() & (df_base['obso_inchcape'] > 0), 1, 0)

# %%
df_base['obso_inchcape'].sum()
# Out:
# 6659060.75

# %% [markdown]
# OBTENCION TRANSITO Y TUBO

# %%
cl_doc = ['ZIPL','ZSTO','ZSPT']
# Assuming your DataFrame is named df_tr
# Assuming 'año' and 'semanas' are already present in the DataFrame

# Apply filters to the DataFrame if needed


# Create a pivot table with 'year' and 'week' as index columns



filtered_df = df_tr[df_tr['Cl.documento compras'].isin(cl_doc)]
filtered_df = filtered_df[['Material','Cantidad','Fecha']]
filtered_df.reset_index(drop=True)
# Out:
#                Material  Cantidad                   Fecha
# 0        PORTADOCSUZUKI         0 2024-08-22 15:23:56.643
# 1      PORTADOCCHANGANP         0 2024-08-22 15:23:56.643
# 2         PORTADOCHAVAL         0 2024-08-22 15:23:56.643
# 3         PORTADCTOKYAL         0 2024-08-04 00:00:00.000
# 4       PORTADOCLOGOGWM         0 2024-08-04 00:00:00.000
# ...                 ...       ...                     ...
# 34010     ALARMG1053OEM       300 2024-08-21 15:23:56.643
# 34011        901001956R         0 2024-09-05 15:23:56.643
# 34012        CSJP02195X         1 2024-08-19 00:00:00.000
# 34013        GJFJ00001P        18 2024-11-08 00:00:00.000
# 34014        GJFJ00013P        10 2024-11-08 00:00:00.000
#
# [34015 rows x 3 columns]

# %%
df_base_2 =df_base

# %%
from datetime import timedelta

# %%
#current_date = datetime.date(2024,6,19)
current_date = datetime.date.today()
print(current_date.isocalendar())
# Crear las columnas en base a las próximas 39 semanas en la base de datos 'b'
for i in range(39):
    week_start = current_date + timedelta(weeks=i)
    year = week_start.year

    nombre_meses = {1: 'jan',2: 'feb',3: 'mar',4: 'apr',5: 'may',6: 'jun',7: 'jul',8: 'aug',9: 'sep',10: 'oct',11: 'nov',12: 'dec'}
    week_number = str(week_start.isocalendar()[1]).zfill(2)
    def nombrar_mes(mes):
        nombre_mes = nombre_meses.get(mes)
        return nombre_mes
    
        
    month_name = nombrar_mes(week_start.month)
    column_name = f"{year}-{month_name}-{week_number}"
    
 
    df_base[column_name] = 0  # Inicializar todas las columnas con 0
# Out:
# datetime.IsoCalendarDate(year=2024, week=30, weekday=3)

# %%
filtered_df['Año'] = filtered_df['Fecha'].dt.year
filtered_df['Month'] = filtered_df['Fecha'].dt.strftime('%B').str.lower().str[:3]
filtered_df['Semana'] = filtered_df['Fecha'].dt.isocalendar().week

# %%
filtered_df = filtered_df[filtered_df['Cantidad']>0]

# %%
df_base_2.columns.to_list()
# Out:
# ['Material actual',
#  'Cod_Actual_1',
#  'Descripción',
#  'Cod. Proveedor',
#  'Proveedor',
#  'Plan Híbrido UN',
#  'Origen',
#  'CES',
#  'PDI',
#  'Nuevo',
#  'Lead Time',
#  'Nro_material',
#  'Material_dsc',
#  'Fecha_creacion',
#  'Tipo_material',
#  'Grupo_articulo',
#  'Grupo_art_desc',
#  'Grupo_art_externo',
#  'Nro_material_antiguo',
#  'Sector',
#  'Sector_dsc',
#  'Jerarquia_producto',
#  'Jquia_desc',
#  'Material_R3',
#  'Part_number',
#  'Tamaño',
#  'Material_S4',
#  'Nodo de Jerarquía',
#  'Familia',
#  'Subfamilia',
#  'Categoría',
#  'Subcatgería',
#  'Modelo',
#  'Stock CD',
#  'Stock Pañol',
#  'FC jul-24',
#  'FC ago-24',
#  'FC sep-24',
#  'FC oct-24',
#  'FC nov-24',
#  'FC dic-24',
#  'FC ene-25',
#  'FC feb-25',
#  'FC mar-25',
#  'FC abr-25',
#  'FC may-25',
#  'Promedio FC',
#  'Promedio FC Piso',
#  'Stock de piso',
#  'Promedio Venta',
#  'Cobertura Stock',
#  'Costo CPP',
#  'MOQ',
#  'Precio Neto',
#  'Moneda',
#  'Vigencia Canal',
#  'Menor a 1',
#  'Semana LT',
#  'Mes LT',
#  'Ultimo Eslabon',
#  'obso_inchcape',
#  'Obsolescencia',
#  '2024-jul-30',
#  '2024-jul-31',
#  '2024-aug-32',
#  '2024-aug-33',
#  '2024-aug-34',
#  '2024-aug-35',
#  '2024-sep-36',
#  '2024-sep-37',
#  '2024-sep-38',
#  '2024-sep-39',
#  '2024-oct-40',
#  '2024-oct-41',
#  '2024-oct-42',
#  '2024-oct-43',
#  '2024-oct-44',
#  '2024-nov-45',
#  '2024-nov-46',
#  '2024-nov-47',
#  '2024-nov-48',
#  '2024-dec-49',
#  '2024-dec-50',
#  '2024-dec-51',
#  '2024-dec-52',
#  '2025-jan-01',
#  '2025-jan-02',
#  '2025-jan-03',
#  '2025-jan-04',
#  '2025-jan-05',
#  '2025-feb-06',
#  '2025-feb-07',
#  '2025-feb-08',
#  '2025-feb-09',
#  '2025-mar-10',
#  '2025-mar-11',
#  '2025-mar-12',
#  '2025-mar-13',
#  '2025-apr-14',
#  '2025-apr-15',
#  '2025-apr-16']

# %%
grouped_sales = filtered_df.groupby(['Material', 'Año', 'Month', 'Semana'])['Cantidad'].sum().reset_index()
grouped_sales['Año'] = grouped_sales['Año'].astype('str')
grouped_sales['Semana'] = grouped_sales['Semana'].astype('int')  # Asegurarse de que Semana sea entero

# Luego, cruzamos los datos de ventas en df_base
for index, row in grouped_sales.iterrows():

    product_code = row['Material']
    week_number = row['Semana']
    year = row['Año']
    column_name_pattern = f"{year}-{week_number:02d}"
    
    # # Encuentra la columna en df_base que contenga el patrón
    matching_columns = [col for col in df_base.columns if f'{year}-' in col and f'-{str(week_number)}' in col]
    
    if matching_columns:
        print(matching_columns)
        matching_column = matching_columns[0]  # Asumimos que solo hay una coincidencia por patrón
        df_base.loc[df_base['Cod_Actual_1'] == product_code, matching_column] = row['Cantidad']
    
# Ahora df_base debe tener las ventas cruzadas en las columnas correspondientes
# Out:
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-oct-43']
# ['2024-sep-37']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-47']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-oct-43']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-sep-37']
# ['2024-nov-47']
# ['2024-sep-37']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-nov-47']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-oct-44']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-oct-44']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-oct-43']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-oct-42']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-jul-31']
# ['2024-aug-35']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-jul-30']
# ['2024-aug-35']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-oct-43']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-40']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-oct-44']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-aug-33']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-sep-37']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-aug-33']
# ['2024-nov-47']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-jul-30']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-aug-33']
# ['2024-aug-35']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-nov-47']
# ['2024-oct-44']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-32']
# ['2024-oct-40']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-44']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-jul-31']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-jul-30']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-jul-30']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-41']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-nov-45']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-nov-47']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-30']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-40']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-40']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-sep-39']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-nov-47']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-41']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-35']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-oct-44']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-oct-40']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-aug-33']
# ['2024-jul-30']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-sep-38']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-nov-46']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-nov-46']
# ['2024-sep-39']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-nov-46']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-aug-35']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-sep-39']
# ['2024-nov-46']
# ['2024-oct-40']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-nov-47']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-nov-47']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-oct-44']
# ['2024-sep-36']
# ['2024-oct-44']
# ['2024-oct-44']
# ['2024-aug-35']
# ['2024-aug-35']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-44']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ...
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-nov-47']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-nov-45']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-nov-48']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-nov-45']
# ['2024-nov-48']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-nov-45']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-aug-35']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-nov-48']
# ['2024-nov-48']
# ['2024-sep-38']
# ['2024-nov-45']
# ['2024-nov-48']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-sep-38']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-nov-47']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-aug-35']
# ['2024-jul-31']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-jul-31']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-sep-38']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-sep-38']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-nov-48']
# ['2024-jul-31']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-nov-47']
# ['2024-nov-47']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-aug-35']
# ['2024-nov-48']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-nov-48']
# ['2024-nov-48']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-oct-43']
# ['2024-sep-38']
# ['2024-oct-43']
# ['2024-aug-32']
# ['2024-nov-45']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-nov-48']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-41']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-oct-43']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-nov-47']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-33']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-sep-37']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-37']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-37']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-nov-46']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-jul-30']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-jul-30']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-jul-30']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-nov-47']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-40']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-sep-39']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-nov-47']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-36']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-jul-31']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-aug-32']
# ['2024-jul-30']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-jul-30']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-jul-31']
# ['2024-sep-38']
# ['2024-aug-32']
# ['2024-sep-38']
# ['2024-sep-38']
# ['2024-nov-48']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-39']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-jul-31']
# ['2024-aug-32']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-oct-41']
# ['2024-nov-48']
# ['2024-oct-43']
# ['2024-aug-34']
# ['2024-aug-35']
# ['2024-nov-47']
# ['2024-oct-43']
# ['2024-sep-36']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-48']
# ['2024-aug-32']
# ['2024-oct-41']
# ['2024-aug-32']
# ['2024-jul-31']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-jul-30']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-48']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-38']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-aug-35']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-aug-33']
# ['2024-sep-36']
# ['2024-nov-47']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-aug-35']
# ['2024-oct-41']
# ['2024-sep-36']
# ['2024-sep-36']
# ['2024-nov-45']
# ['2024-nov-45']
# ['2024-sep-36']
# ['2024-aug-33']
# ['2024-nov-45']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-32']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-sep-36']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-32']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-sep-36']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-47']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-38']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-nov-46']
# ['2024-nov-46']
# ['2024-aug-33']
# ['2024-aug-34']
# ['2024-oct-42']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-sep-37']
# ['2024-nov-46']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-aug-33']
# ['2024-oct-42']
# ['2024-sep-37']
# ['2024-nov-45']
# ['2024-oct-41']
# ['2024-oct-42']
# ['2024-sep-39']
# ['2024-oct-40']
# ['2024-oct-42']
# ['2024-aug-34']
# ['2024-aug-34']
# ['2024-oct-42']

# %%
df_base['Faltante AP'] = 0

# %%
df_base = df_base.fillna(0)

# %%
meses_ingles_español = {
    "jan": "ene",
    "feb": "feb",
    "mar": "mar",
    "apr": "abr",
    "may": "may",
    "jun": "jun",
    "jul": "jul",
    "aug": "ago",
    "sep": "sep",
    "oct": "oct",
    "nov": "nov",
    "dec": "dic"
}
def obtener_mes_español(mes):
    mes_español = meses_ingles_español.get(mes)
    if mes_español:
        return mes_español.lower()
    else:
        return None

# %%
year_columns = [col for col in df_base.columns if col.split('-')[0].isdigit() and 'POS-STOCK' not in col]

nueva_columna = f'POS-STOCK-{year_columns[0]}'
df_base[nueva_columna] = df_base.apply(lambda row:  row['Stock CD'] + row['Stock Pañol'], axis=1)

# %%
for col in year_columns[1:]:
    column_name = f'POS-STOCK-{col}'
    
    last_column_name = df_base.columns[-1]
    year_month = last_column_name[-11:]
    
    mes = col[5:8]
    año = col[2:4]

   

    mes_español = obtener_mes_español(mes)
    if mes_español is None:
        print(f"Could not find Spanish equivalent for month: {mes}")
        continue

    columna_fc = f'FC {mes_español}-{año}'
    columna_tr = year_month

    



    calculo_columna = np.where((df_base[last_column_name] + df_base[columna_tr] - df_base[columna_fc]) < 0, 0, df_base[last_column_name] + df_base[columna_tr] - df_base[columna_fc])
    
    df_base[column_name] = calculo_columna
    print(column_name)
# Out:
# POS-STOCK-2024-jul-31
# POS-STOCK-2024-aug-32
# POS-STOCK-2024-aug-33
# POS-STOCK-2024-aug-34
# POS-STOCK-2024-aug-35
# POS-STOCK-2024-sep-36
# POS-STOCK-2024-sep-37
# POS-STOCK-2024-sep-38
# POS-STOCK-2024-sep-39
# POS-STOCK-2024-oct-40
# POS-STOCK-2024-oct-41
# POS-STOCK-2024-oct-42
# POS-STOCK-2024-oct-43
# POS-STOCK-2024-oct-44
# POS-STOCK-2024-nov-45
# POS-STOCK-2024-nov-46
# POS-STOCK-2024-nov-47
# POS-STOCK-2024-nov-48
# POS-STOCK-2024-dec-49
# POS-STOCK-2024-dec-50
# POS-STOCK-2024-dec-51
# POS-STOCK-2024-dec-52
# POS-STOCK-2025-jan-01
# POS-STOCK-2025-jan-02
# POS-STOCK-2025-jan-03
# POS-STOCK-2025-jan-04
# POS-STOCK-2025-jan-05
# POS-STOCK-2025-feb-06
# POS-STOCK-2025-feb-07
# POS-STOCK-2025-feb-08
# POS-STOCK-2025-feb-09
# POS-STOCK-2025-mar-10
# POS-STOCK-2025-mar-11
# POS-STOCK-2025-mar-12
# POS-STOCK-2025-mar-13
# POS-STOCK-2025-apr-14
# POS-STOCK-2025-apr-15
# POS-STOCK-2025-apr-16

# %%
df_base_aux = df_base



pos_columns = [col for col in df_base_aux.columns if 'POS-STOCK' in col]

pos_columns[0][15:18]
pos_columns[0][12:14]
mes = pos_columns[0][15:18]
año = pos_columns[0][12:14]

mes_español = obtener_mes_español(mes)
if mes_español is None:
    print(f"Could not find Spanish equivalent for month: {mes}")
    



columna_fc = f'FC {mes_español}-{año}'
df_base_aux[f'COBERTURA-{pos_columns[0][10:]}']= (df_base_aux[f'POS-STOCK-{pos_columns[0][10:]}']/((df_base_aux[columna_fc]/2)))
df_base_aux[f'COBERTURA-{pos_columns[0][10:]}'].replace([np.inf, -np.inf, np.nan], '-', inplace=True)
mes = pos_columns[1][15:18]
año = pos_columns[1][12:14]

mes_español = obtener_mes_español(mes)
if mes_español is None:
    print(f"Could not find Spanish equivalent for month: {mes}")
    



columna_fc = f'FC {mes_español}-{año}'
df_base_aux[f'COBERTURA-{pos_columns[1][10:]}']= (df_base_aux[f'POS-STOCK-{pos_columns[1][10:]}']/df_base_aux[columna_fc])
df_base_aux[f'COBERTURA-{pos_columns[1][10:]}'].replace([np.inf, -np.inf, np.nan], '-', inplace=True)

for col in pos_columns[2:]:
    column_name = f'COBERTURA-{col[10:]}'
    
   
    mes = col[15:18]
    año = col[12:14]

    mes_español = obtener_mes_español(mes)
    if mes_español is None:
        print(f"Could not find Spanish equivalent for month: {mes}")
        



    columna_fc = f'FC {mes_español}-{año}'






    df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])

    df_base_aux[column_name].replace([np.inf, -np.inf, np.nan], '-', inplace=True)
# Set display options to show all columns and rows without truncation

# Display the DataFrame without column truncation
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\1005272991.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[column_name]= (df_base_aux[f'POS-STOCK-{column_name[10:]}']/df_base_aux[columna_fc])

# %%
df_base_aux['transito'] = df_base[year_columns].sum(axis=1)
    

df_base_aux['pos_stock'] = df_base_aux['Stock CD'] + df_base_aux['Stock Pañol'] + df_base_aux['transito']
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2957695723.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux['transito'] = df_base[year_columns].sum(axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2957695723.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux['pos_stock'] = df_base_aux['Stock CD'] + df_base_aux['Stock Pañol'] + df_base_aux['transito']

# %%
cob_columns = [col for col in df_base_aux.columns if 'COBERTURA' in col]
# for c in cob_columns:
#     print(c[10:])

for col in cob_columns:
    nombre_columna = f'CUMPLIMIENTO-{col[10:]}'

    def calculate_value(row):
       
        cobertura = row[col]
        pos_stock_semanal = row[f'POS-STOCK-{col[10:]}']
        
        if cobertura == '-':
            return 1
        elif cobertura > 1:
            return 1
        elif cobertura < 0:
            return 0
        else:       
            return cobertura
        

        #cobertura es '-', y pos stock de esa semana es > 0 , 1
        #cobertura es '-', y pos stock de esa semana es 0 , 0

    # Apply the function row-wise using apply() and axis=1
    df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\3466767905.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux.apply(calculate_value, axis=1)

# %%
cump_cols = [col for col in df_base_aux.columns if 'CUMPLIMIENTO' in col]

# %%
for col in cump_cols:
    nombre_columna = f'NNSS_P - {col[13:]}'
    mes = col[18:21]
    año = col[15:17]

    mes_español = obtener_mes_español(mes)
    if mes_español is None:
        print(f"Could not find Spanish equivalent for month: {mes}")
        



    columna_fc = f'FC {mes_español}-{año}'

    df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\497526337.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]

# %%
ns_cols = [col for col in df_base_aux.columns if 'NNSS_P' in col]

# %%
for col in ns_cols:

    mes = col[14:17]
    año = col[11:13]
    #print(nombre_columna)

    

    mes_español = obtener_mes_español(mes)
    if mes_español is None:
        print(f"Could not find Spanish equivalent for month: {mes}")


    nombre_columna = f'forecast - {col[9:]}'
    
    
    columna_fc = f'FC {mes_español}-{año}'

    

    df_base_aux[nombre_columna] = df_base_aux[columna_fc]


        



    # columna_fc = f'FC {mes_español}-{año}'

    # df_base_aux[nombre_columna] = df_base[col] * df_base_aux[columna_fc]
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\646941158.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux[nombre_columna] = df_base_aux[columna_fc]

# %%
cump_cols = [col for col in df_base_aux.columns if 'CUMPLIMIENTO' in col]

df_base_aux['NNSS_Promedio'] = df_base_aux[cump_cols[:20]].mean(axis=1)
df_base_aux['NNSS_Promedio_Aereo'] = df_base_aux[cump_cols[:12]].mean(axis=1)
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2092297865.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux['NNSS_Promedio'] = df_base_aux[cump_cols[:20]].mean(axis=1)
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_20204\2092297865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_base_aux['NNSS_Promedio_Aereo'] = df_base_aux[cump_cols[:12]].mean(axis=1)

# %%
df_base_aux.to_excel('C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Disponibilidad Futura/2024/AXS/bases_python/Base_Final.xlsx')

# %%
sub_df = df_base_aux.filter(regex='^Cod_Actual_1$|^NNSS_P - ')
sub_df_2 = df_base_aux.filter(regex = '^Cod_Actual_1$|^forecast - ')

# %%
sub_df[sub_df['Cod_Actual_1']=='ADHESIVODIESEL']
# Out:
#        Cod_Actual_1  NNSS_P - 2024-jul-30  NNSS_P - 2024-jul-31  \
# 151  ADHESIVODIESEL             34.313164             34.313164
#
#      NNSS_P - 2024-aug-32  NNSS_P - 2024-aug-33  NNSS_P - 2024-aug-34  \
# 151             33.389376             33.389376             33.389376
#
#      NNSS_P - 2024-aug-35  NNSS_P - 2024-sep-36  NNSS_P - 2024-sep-37  \
# 151             33.389376             41.010624             41.010624
#
#      NNSS_P - 2024-sep-38  ...  NNSS_P - 2025-feb-07  NNSS_P - 2025-feb-08  \
# 151             41.010624  ...             24.942263             24.942263
#
#      NNSS_P - 2025-feb-09  NNSS_P - 2025-mar-10  NNSS_P - 2025-mar-11  \
# 151             24.942263             24.942263             24.942263
#
#      NNSS_P - 2025-mar-12  NNSS_P - 2025-mar-13  NNSS_P - 2025-apr-14  \
# 151             24.942263             24.942263              28.17552
#
#      NNSS_P - 2025-apr-15  NNSS_P - 2025-apr-16
# 151              28.17552              28.17552
#
# [1 rows x 40 columns]

# %%
sub_df.columns
# Out:
# Index(['Cod_Actual_1', 'NNSS_P - 2024-jul-30', 'NNSS_P - 2024-jul-31',
#        'NNSS_P - 2024-aug-32', 'NNSS_P - 2024-aug-33', 'NNSS_P - 2024-aug-34',
#        'NNSS_P - 2024-aug-35', 'NNSS_P - 2024-sep-36', 'NNSS_P - 2024-sep-37',
#        'NNSS_P - 2024-sep-38', 'NNSS_P - 2024-sep-39', 'NNSS_P - 2024-oct-40',
#        'NNSS_P - 2024-oct-41', 'NNSS_P - 2024-oct-42', 'NNSS_P - 2024-oct-43',
#        'NNSS_P - 2024-oct-44', 'NNSS_P - 2024-nov-45', 'NNSS_P - 2024-nov-46',
#        'NNSS_P - 2024-nov-47', 'NNSS_P - 2024-nov-48', 'NNSS_P - 2024-dec-49',
#        'NNSS_P - 2024-dec-50', 'NNSS_P - 2024-dec-51', 'NNSS_P - 2024-dec-52',
#        'NNSS_P - 2025-jan-01', 'NNSS_P - 2025-jan-02', 'NNSS_P - 2025-jan-03',
#        'NNSS_P - 2025-jan-04', 'NNSS_P - 2025-jan-05', 'NNSS_P - 2025-feb-06',
#        'NNSS_P - 2025-feb-07', 'NNSS_P - 2025-feb-08', 'NNSS_P - 2025-feb-09',
#        'NNSS_P - 2025-mar-10', 'NNSS_P - 2025-mar-11', 'NNSS_P - 2025-mar-12',
#        'NNSS_P - 2025-mar-13', 'NNSS_P - 2025-apr-14', 'NNSS_P - 2025-apr-15',
#        'NNSS_P - 2025-apr-16'],
#       dtype='object')

# %%
#declarar id
id_vars = ['Cod_Actual_1']



# Luego, usamos melt para transformar el DataFrame
df_transformado = pd.melt(sub_df, id_vars=id_vars, var_name='NNSS - AÑO-MES-SEM', value_name='Cumplimiento')

df_transformado_2 = pd.melt(sub_df_2, id_vars=id_vars, var_name='FC SEM', value_name='Forecast')


# Puedes resetear los índices si lo deseas
df_transformado.reset_index(drop=True, inplace=True)
#f_transformado_2.reset_index(drop=True, inplace=True)





# Ahora df_transformado contiene el DataFrame transformado como lo necesitas

# %%
df_transformado_2['FC SEM'] = df_transformado_2['FC SEM'].str[11:]

# %%
df_transformado_2
# Out:
#              Cod_Actual_1       FC SEM   Forecast  \
# 0               00008BN10  2024-jul-30   0.135153
# 1               00008BR12  2024-jul-30   0.000000
# 2               00008BR23  2024-jul-30   1.028675
# 3              00008LN10B  2024-jul-30   0.000000
# 4               00008LN11  2024-jul-30   0.854866
# ...                   ...          ...        ...
# 15400            WT449721  2025-apr-16   0.000031
# 15401  YAKIMARIGDEBACK4BI  2025-apr-16   0.000000
# 15402            YE-CN010  2025-apr-16   0.000000
# 15403           ZGARDXCAR  2025-apr-16  16.473889
# 15404           ZGARDXCUS  2025-apr-16  16.386797
#
#                                   ID
# 0               00008BN102024-jul-30
# 1               00008BR122024-jul-30
# 2               00008BR232024-jul-30
# 3              00008LN10B2024-jul-30
# 4               00008LN112024-jul-30
# ...                              ...
# 15400            WT4497212025-apr-16
# 15401  YAKIMARIGDEBACK4BI2025-apr-16
# 15402            YE-CN0102025-apr-16
# 15403           ZGARDXCAR2025-apr-16
# 15404           ZGARDXCUS2025-apr-16
#
# [15405 rows x 4 columns]

# %%
df_transformado_2['ID'] = df_transformado_2['Cod_Actual_1'] + df_transformado_2['FC SEM']

# %%
df_transformado_2
# Out:
#              Cod_Actual_1       FC SEM   Forecast  \
# 0               00008BN10  2024-jul-30   0.135153
# 1               00008BR12  2024-jul-30   0.000000
# 2               00008BR23  2024-jul-30   1.028675
# 3              00008LN10B  2024-jul-30   0.000000
# 4               00008LN11  2024-jul-30   0.854866
# ...                   ...          ...        ...
# 15400            WT449721  2025-apr-16   0.000031
# 15401  YAKIMARIGDEBACK4BI  2025-apr-16   0.000000
# 15402            YE-CN010  2025-apr-16   0.000000
# 15403           ZGARDXCAR  2025-apr-16  16.473889
# 15404           ZGARDXCUS  2025-apr-16  16.386797
#
#                                   ID
# 0               00008BN102024-jul-30
# 1               00008BR122024-jul-30
# 2               00008BR232024-jul-30
# 3              00008LN10B2024-jul-30
# 4               00008LN112024-jul-30
# ...                              ...
# 15400            WT4497212025-apr-16
# 15401  YAKIMARIGDEBACK4BI2025-apr-16
# 15402            YE-CN0102025-apr-16
# 15403           ZGARDXCAR2025-apr-16
# 15404           ZGARDXCUS2025-apr-16
#
# [15405 rows x 4 columns]

# %%
df_transformado
# Out:
#              Cod_Actual_1    NNSS - AÑO-MES-SEM  Cumplimiento
# 0               00008BN10  NNSS_P - 2024-jul-30      0.135153
# 1               00008BR12  NNSS_P - 2024-jul-30      0.000000
# 2               00008BR23  NNSS_P - 2024-jul-30      1.028675
# 3              00008LN10B  NNSS_P - 2024-jul-30      0.000000
# 4               00008LN11  NNSS_P - 2024-jul-30      0.854866
# ...                   ...                   ...           ...
# 15400            WT449721  NNSS_P - 2025-apr-16      0.000031
# 15401  YAKIMARIGDEBACK4BI  NNSS_P - 2025-apr-16      0.000000
# 15402            YE-CN010  NNSS_P - 2025-apr-16      0.000000
# 15403           ZGARDXCAR  NNSS_P - 2025-apr-16      0.000000
# 15404           ZGARDXCUS  NNSS_P - 2025-apr-16      0.000000
#
# [15405 rows x 3 columns]

# %%
df_transformado['ID_AUX'] = df_transformado['NNSS - AÑO-MES-SEM'].str[9:]

# %%
df_transformado
# Out:
#              Cod_Actual_1    NNSS - AÑO-MES-SEM  Cumplimiento       ID_AUX
# 0               00008BN10  NNSS_P - 2024-jul-30      0.135153  2024-jul-30
# 1               00008BR12  NNSS_P - 2024-jul-30      0.000000  2024-jul-30
# 2               00008BR23  NNSS_P - 2024-jul-30      1.028675  2024-jul-30
# 3              00008LN10B  NNSS_P - 2024-jul-30      0.000000  2024-jul-30
# 4               00008LN11  NNSS_P - 2024-jul-30      0.854866  2024-jul-30
# ...                   ...                   ...           ...          ...
# 15400            WT449721  NNSS_P - 2025-apr-16      0.000031  2025-apr-16
# 15401  YAKIMARIGDEBACK4BI  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15402            YE-CN010  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15403           ZGARDXCAR  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15404           ZGARDXCUS  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
#
# [15405 rows x 4 columns]

# %%
df_transformado['ID'] = df_transformado['Cod_Actual_1'] + df_transformado['ID_AUX']

# %%
df_transformado.nunique()
# Out:
# Cod_Actual_1            395
# NNSS - AÑO-MES-SEM       39
# Cumplimiento            913
# ID_AUX                   39
# ID                    15405
# dtype: int64

# %%
df_transformado = df_transformado.merge(df_transformado_2, left_on='ID',right_on='ID', how='left')

# %%
df_transformado[df_transformado['Cod_Actual_1']=='ADHESIVODIESEL']
# Out:
#          Cod_Actual_1    NNSS - AÑO-MES-SEM  Cumplimiento   Forecast
# 151    ADHESIVODIESEL  NNSS_P - 2024-jul-30     34.313164  34.313164
# 546    ADHESIVODIESEL  NNSS_P - 2024-jul-31     34.313164  34.313164
# 941    ADHESIVODIESEL  NNSS_P - 2024-aug-32     33.389376  33.389376
# 1336   ADHESIVODIESEL  NNSS_P - 2024-aug-33     33.389376  33.389376
# 1731   ADHESIVODIESEL  NNSS_P - 2024-aug-34     33.389376  33.389376
# 2126   ADHESIVODIESEL  NNSS_P - 2024-aug-35     33.389376  33.389376
# 2521   ADHESIVODIESEL  NNSS_P - 2024-sep-36     41.010624  41.010624
# 2916   ADHESIVODIESEL  NNSS_P - 2024-sep-37     41.010624  41.010624
# 3311   ADHESIVODIESEL  NNSS_P - 2024-sep-38     41.010624  41.010624
# 3706   ADHESIVODIESEL  NNSS_P - 2024-sep-39     41.010624  41.010624
# 4101   ADHESIVODIESEL  NNSS_P - 2024-oct-40     23.787529  23.787529
# 4496   ADHESIVODIESEL  NNSS_P - 2024-oct-41     23.787529  23.787529
# 4891   ADHESIVODIESEL  NNSS_P - 2024-oct-42     23.787529  23.787529
# 5286   ADHESIVODIESEL  NNSS_P - 2024-oct-43     23.787529  23.787529
# 5681   ADHESIVODIESEL  NNSS_P - 2024-oct-44     23.787529  23.787529
# 6076   ADHESIVODIESEL  NNSS_P - 2024-nov-45     25.404157  25.404157
# 6471   ADHESIVODIESEL  NNSS_P - 2024-nov-46     25.404157  25.404157
# 6866   ADHESIVODIESEL  NNSS_P - 2024-nov-47     25.404157  25.404157
# 7261   ADHESIVODIESEL  NNSS_P - 2024-nov-48     25.404157  25.404157
# 7656   ADHESIVODIESEL  NNSS_P - 2024-dec-49     20.323326  20.323326
# 8051   ADHESIVODIESEL  NNSS_P - 2024-dec-50     20.323326  20.323326
# 8446   ADHESIVODIESEL  NNSS_P - 2024-dec-51     20.323326  20.323326
# 8841   ADHESIVODIESEL  NNSS_P - 2024-dec-52     20.323326  20.323326
# 9236   ADHESIVODIESEL  NNSS_P - 2025-jan-01     26.789838  26.789838
# 9631   ADHESIVODIESEL  NNSS_P - 2025-jan-02     26.789838  26.789838
# 10026  ADHESIVODIESEL  NNSS_P - 2025-jan-03     26.789838  26.789838
# 10421  ADHESIVODIESEL  NNSS_P - 2025-jan-04     26.789838  26.789838
# 10816  ADHESIVODIESEL  NNSS_P - 2025-jan-05     26.789838  26.789838
# 11211  ADHESIVODIESEL  NNSS_P - 2025-feb-06     24.942263  24.942263
# 11606  ADHESIVODIESEL  NNSS_P - 2025-feb-07     24.942263  24.942263
# 12001  ADHESIVODIESEL  NNSS_P - 2025-feb-08     24.942263  24.942263
# 12396  ADHESIVODIESEL  NNSS_P - 2025-feb-09     24.942263  24.942263
# 12791  ADHESIVODIESEL  NNSS_P - 2025-mar-10     24.942263  24.942263
# 13186  ADHESIVODIESEL  NNSS_P - 2025-mar-11     24.942263  24.942263
# 13581  ADHESIVODIESEL  NNSS_P - 2025-mar-12     24.942263  24.942263
# 13976  ADHESIVODIESEL  NNSS_P - 2025-mar-13     24.942263  24.942263
# 14371  ADHESIVODIESEL  NNSS_P - 2025-apr-14     28.175520  28.175520
# 14766  ADHESIVODIESEL  NNSS_P - 2025-apr-15     28.175520  28.175520
# 15161  ADHESIVODIESEL  NNSS_P - 2025-apr-16     28.175520  28.175520

# %%
df_transformado.columns
# Out:
# Index(['Cod_Actual_1_x', 'NNSS - AÑO-MES-SEM', 'Cumplimiento', 'ID_AUX', 'ID',
#        'Cod_Actual_1_y', 'FC SEM', 'Forecast'],
#       dtype='object')

# %%
df_transformado
# Out:
#            Cod_Actual_1_x    NNSS - AÑO-MES-SEM  Cumplimiento       ID_AUX  \
# 0               00008BN10  NNSS_P - 2024-jul-30      0.135153  2024-jul-30
# 1               00008BR12  NNSS_P - 2024-jul-30      0.000000  2024-jul-30
# 2               00008BR23  NNSS_P - 2024-jul-30      1.028675  2024-jul-30
# 3              00008LN10B  NNSS_P - 2024-jul-30      0.000000  2024-jul-30
# 4               00008LN11  NNSS_P - 2024-jul-30      0.854866  2024-jul-30
# ...                   ...                   ...           ...          ...
# 15400            WT449721  NNSS_P - 2025-apr-16      0.000031  2025-apr-16
# 15401  YAKIMARIGDEBACK4BI  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15402            YE-CN010  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15403           ZGARDXCAR  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
# 15404           ZGARDXCUS  NNSS_P - 2025-apr-16      0.000000  2025-apr-16
#
#                                   ID      Cod_Actual_1_y       FC SEM  \
# 0               00008BN102024-jul-30           00008BN10  2024-jul-30
# 1               00008BR122024-jul-30           00008BR12  2024-jul-30
# 2               00008BR232024-jul-30           00008BR23  2024-jul-30
# 3              00008LN10B2024-jul-30          00008LN10B  2024-jul-30
# 4               00008LN112024-jul-30           00008LN11  2024-jul-30
# ...                              ...                 ...          ...
# 15400            WT4497212025-apr-16            WT449721  2025-apr-16
# 15401  YAKIMARIGDEBACK4BI2025-apr-16  YAKIMARIGDEBACK4BI  2025-apr-16
# 15402            YE-CN0102025-apr-16            YE-CN010  2025-apr-16
# 15403           ZGARDXCAR2025-apr-16           ZGARDXCAR  2025-apr-16
# 15404           ZGARDXCUS2025-apr-16           ZGARDXCUS  2025-apr-16
#
#         Forecast
# 0       0.135153
# 1       0.000000
# 2       1.028675
# 3       0.000000
# 4       0.854866
# ...          ...
# 15400   0.000031
# 15401   0.000000
# 15402   0.000000
# 15403  16.473889
# 15404  16.386797
#
# [15405 rows x 8 columns]

# %%
rename_cols = {'Cod_Actual_1_x':'Cod_Actual_1'}
df_transformado.drop('Cod_Actual_1_y', inplace = True, axis=1)
df_transformado.rename(columns=rename_cols, inplace = True)

# %%
reducir_cols = ['Cod_Actual_1','NNSS - AÑO-MES-SEM','Cumplimiento','Forecast']

# %%
df_transformado = df_transformado[reducir_cols]

# %%
df_transformado.to_csv('C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Disponibilidad Futura/2024/AXS/bases_python/base_pbi.csv')

# %%
df_mara.dropna(subset=['Material_R3'], inplace=True)

# Assuming 'df_mara' is your DataFrame

# %%
# Eliminar duplicados basados en la columna 'Material_R3'
df_mara.drop_duplicates(subset=['Material_R3'], inplace=True)

# %%
df_mara.dtypes
# Out:
# Nro_material             object
# Material_dsc             object
# Fecha_creacion            int64
# Tipo_material            object
# Grupo_articulo           object
# Grupo_art_desc           object
# Grupo_art_externo        object
# Nro_material_antiguo     object
# Sector                  float64
# Sector_dsc               object
# Jerarquia_producto      float64
# Jquia_desc               object
# Material_R3              object
# Part_number              object
# Tamaño                   object
# Material_S4              object
# Nodo de Jerarquía        object
# Familia                  object
# Subfamilia               object
# Categoría                object
# Subcatgería              object
# Modelo                   object
# dtype: object

# %%
df_mara.to_csv('C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Disponibilidad Futura/2024/AXS/bases_python/mara_tratada.csv')
